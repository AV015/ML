# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv", header=1)
df_copy = pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv", header=1)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.shape
# Out:
# (246, 14)

# %%
df.isna().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df[~df['day'].str.isnumeric()]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 123  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes
# 123  FWI  Classes

# %%
df.drop(index=123, inplace=True)

# %%
df[df['day'].str.isnumeric()].shape
# Out:
# (243, 14)

# %%
df.shape
# Out:
# (243, 14)

# %%
df.rename(columns={'Classes  ':'Classes'}, inplace=True)

# %%
col = df.columns
col
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
for i in ['day', 'month', 'year' , 'Temperature', 'RH', 'Ws'] :
    df[i] = df[i].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 28.5+ KB

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4    5      6  2012           27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI    Classes
# 0  0.5  not fire
# 1  0.4  not fire
# 2  0.1  not fire
# 3    0  not fire
# 4  0.5  not fire

# %%
for i in ['Rain','FFMC', 'DMC', 'DC', 'ISI', 'BUI','FWI'] :
    df[i] = df[i].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 28.5+ KB

# %%
df['Classes'].replace('not fire    ','not fire', inplace = True)

# %%
df['Classes'].unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %%
df['Classes'].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
df = pd.get_dummies(df, columns=['Classes'])

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 241   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 242   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 243   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 244   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 245   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   day               243 non-null    int64
#  1   month             243 non-null    int64
#  2   year              243 non-null    int64
#  3   Temperature       243 non-null    int64
#  4   RH                243 non-null    int64
#  5   Ws                243 non-null    int64
#  6   Rain              243 non-null    float64
#  7   FFMC              243 non-null    float64
#  8   DMC               243 non-null    float64
#  9   DC                243 non-null    float64
#  10  ISI               243 non-null    float64
#  11  BUI               243 non-null    float64
#  12  FWI               243 non-null    float64
#  13  Classes_fire      243 non-null    uint8
#  14  Classes_not fire  243 non-null    uint8
# dtypes: float64(7), int64(6), uint8(2)
# memory usage: 35.2 KB

# %%
col = df.columns
col
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes_fire', 'Classes_not fire'],
#       dtype='object')

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=9 :
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# /var/folders/_v/cxr311d57jxg2gg6hwj9c95m0000gn/T/ipykernel_984/993132861.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /var/folders/_v/cxr311d57jxg2gg6hwj9c95m0000gn/T/ipykernel_984/993132861.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=9 :
        ax = plt.subplot(3,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()

# %%
q = df['Ws'].quantile(0.97)
df_cleaned = df[df['Ws'] < q]

q = df['Rain'].quantile(0.90)
df_cleaned = df_cleaned[df_cleaned['Rain'] < q]

q = df['FFMC'].quantile(0.95)
df_cleaned = df_cleaned[df_cleaned['FFMC'] < q]

q = df['DMC'].quantile(0.95)
df_cleaned = df_cleaned[df_cleaned['DMC'] < q]

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df_cleaned:
    if plotnumber<=9 :
        ax = plt.subplot(3,3,plotnumber)
        sns.boxplot(df_cleaned[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()

# %%
df.shape, df_cleaned.shape
# Out:
# ((243, 15), (186, 15))

# %%
df_cleaned.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes_fire', 'Classes_not fire'],
#       dtype='object')

# %%
df_cleaned.drop(['Classes_fire', 'Classes_not fire'],axis = 1, inplace=True)

# %%
df_copy.rename({'Classes  ' : 'Classes'}, inplace=True)

# %%
df_cleaned['Classes'] = df_copy['Classes  ']

# %%
df_cleaned
# Out:
#      day  month  Temperature  RH  Ws  Rain  FFMC   DMC     DC  ISI   BUI  \
# 0      1      6           29  57  18   0.0  65.7   3.4    7.6  1.3   3.4
# 1      2      6           29  61  13   1.3  64.4   4.1    7.6  1.0   3.9
# 2      5      6           27  77  16   0.0  64.8   3.0   14.2  1.2   3.9
# 3      6      6           31  67  14   0.0  82.6   5.8   22.2  3.1   7.0
# 4      7      6           33  54  13   0.0  88.2   9.9   30.5  6.4  10.9
# ..   ...    ...          ...  ..  ..   ...   ...   ...    ...  ...   ...
# 181   23      9           35  56  14   0.0  89.0  29.4  115.6  7.5  36.0
# 182   25      9           28  70  15   0.0  79.9  13.8   36.1  2.4  14.1
# 183   26      9           30  65  14   0.0  85.4  16.0   44.5  4.5  16.9
# 184   29      9           24  54  18   0.1  79.7   4.3   15.2  1.7   5.1
# 185   30      9           24  64  15   0.2  67.3   3.8   16.5  1.2   4.8
#
#       FWI  Classes_encode
# 0     0.5               2
# 1     0.4               2
# ...

# %%
X = df_cleaned.drop(['Classes_encode'], axis = 1)
y = df_cleaned['Classes_encode']

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder
scaler = StandardScaler()
le = LabelEncoder()

df_cleaned['Classes_encode'] = le.fit_transform(df_cleaned['Classes'])
df_cleaned
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC     DC  ISI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4    7.6  1.3
# 1      2      6  2012           29  61  13   1.3  64.4   4.1    7.6  1.0
# 4      5      6  2012           27  77  16   0.0  64.8   3.0   14.2  1.2
# 5      6      6  2012           31  67  14   0.0  82.6   5.8   22.2  3.1
# 6      7      6  2012           33  54  13   0.0  88.2   9.9   30.5  6.4
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...    ...  ...
# 238   23      9  2012           35  56  14   0.0  89.0  29.4  115.6  7.5
# 240   25      9  2012           28  70  15   0.0  79.9  13.8   36.1  2.4
# 241   26      9  2012           30  65  14   0.0  85.4  16.0   44.5  4.5
# 244   29      9  2012           24  54  18   0.1  79.7   4.3   15.2  1.7
# 245   30      9  2012           24  64  15   0.2  67.3   3.8   16.5  1.2
#
#       BUI   FWI       Classes  Classes_encode
# ...

# %%
df_cleaned.drop(['Classes'], axis=1, inplace=True)

# %%
df_cleaned.drop(['year'], axis=1, inplace=True)

# %%
df_cleaned
# Out:
#      day  month  Temperature  RH  Ws  Rain  FFMC   DMC     DC  ISI   BUI  \
# 0      1      6           29  57  18   0.0  65.7   3.4    7.6  1.3   3.4
# 1      2      6           29  61  13   1.3  64.4   4.1    7.6  1.0   3.9
# 4      5      6           27  77  16   0.0  64.8   3.0   14.2  1.2   3.9
# 5      6      6           31  67  14   0.0  82.6   5.8   22.2  3.1   7.0
# 6      7      6           33  54  13   0.0  88.2   9.9   30.5  6.4  10.9
# ..   ...    ...          ...  ..  ..   ...   ...   ...    ...  ...   ...
# 238   23      9           35  56  14   0.0  89.0  29.4  115.6  7.5  36.0
# 240   25      9           28  70  15   0.0  79.9  13.8   36.1  2.4  14.1
# 241   26      9           30  65  14   0.0  85.4  16.0   44.5  4.5  16.9
# 244   29      9           24  54  18   0.1  79.7   4.3   15.2  1.7   5.1
# 245   30      9           24  64  15   0.2  67.3   3.8   16.5  1.2   4.8
#
#       FWI  Classes_encode
# 0     0.5               2
# 1     0.4               2
# ...

# %%
df_cleaned.reset_index(inplace=True)

# %%
df_cleaned.columns.droplevel()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 df_cleaned.columns.droplevel()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:2182, in Index.droplevel(self, level)
#    2178     level = [level]
#    2180 levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
# -> 2182 return self._drop_level_numbers(levnums)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:2193, in Index._drop_level_numbers(self, levnums)
#    2191     return self
#    2192 if len(levnums) >= self.nlevels:
# -> 2193     raise ValueError(
#    2194         f"Cannot remove {len(levnums)} levels from an index with "
#    2195         f"{self.nlevels} levels: at least one level must be left."
#    2196     )
# ...

# %%
df_cleaned.drop('index', axis = 1, inplace=True)

# %%
df_cleaned
# Out:
#      day  month  Temperature  RH  Ws  Rain  FFMC   DMC     DC  ISI   BUI  \
# 0      1      6           29  57  18   0.0  65.7   3.4    7.6  1.3   3.4
# 1      2      6           29  61  13   1.3  64.4   4.1    7.6  1.0   3.9
# 2      5      6           27  77  16   0.0  64.8   3.0   14.2  1.2   3.9
# 3      6      6           31  67  14   0.0  82.6   5.8   22.2  3.1   7.0
# 4      7      6           33  54  13   0.0  88.2   9.9   30.5  6.4  10.9
# ..   ...    ...          ...  ..  ..   ...   ...   ...    ...  ...   ...
# 181   23      9           35  56  14   0.0  89.0  29.4  115.6  7.5  36.0
# 182   25      9           28  70  15   0.0  79.9  13.8   36.1  2.4  14.1
# 183   26      9           30  65  14   0.0  85.4  16.0   44.5  4.5  16.9
# 184   29      9           24  54  18   0.1  79.7   4.3   15.2  1.7   5.1
# 185   30      9           24  64  15   0.2  67.3   3.8   16.5  1.2   4.8
#
#       FWI  Classes_encode
# 0     0.5               2
# 1     0.4               2
# ...

# %%
X = scaler.fit_transform(X)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25, random_state=15)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,f1_score,precision_score,recall_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9361702127659575
